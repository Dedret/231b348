# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.

n = int(input("Enter the number of elements: "))

numbers = []
for i in range(n):
    element = int(input(f"Enter element {i+1}: "))
    numbers.append(element)


for i in range(n):
    min_index = i

    for j in range(i + 1, n):
        if numbers[j] < numbers[min_index]:
            min_index = j


    numbers[i], numbers[min_index] = numbers[min_index], numbers[i]


print("Sorted list:", numbers)
# Out:
# Enter the number of elements: 8
# Enter element 1: 5
# Enter element 2: 9
# Enter element 3: 7
# Enter element 4: 8
# Enter element 5: 6
# Enter element 6: 2
# Enter element 7: 4
# Enter element 8: 10
# Sorted list: [2, 4, 5, 6, 7, 8, 9, 10]

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import random
import time
import matplotlib.pyplot as plt

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result


def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

sizes = [100, 500, 1000, 2000, 5000, 10000]
times = []

for n in sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]

    start_time = time.time()
    merge_sort(arr)
    end_time = time.time()

    times.append(end_time - start_time)
    print(f"n = {n}, Time taken = {end_time - start_time:.6f} seconds")

plt.plot(sizes, times, marker='o', color='blue')
plt.title("Merge Sort: Time Taken vs Input Size (n)")
plt.xlabel("Input Size (n)")
plt.ylabel("Time (seconds)")
plt.grid(True)

plt.show()
# Out:
# n = 100, Time taken = 0.000839 seconds
# n = 500, Time taken = 0.001656 seconds
# n = 1000, Time taken = 0.003592 seconds
# n = 2000, Time taken = 0.010355 seconds
# n = 5000, Time taken = 0.008831 seconds
# n = 10000, Time taken = 0.018865 seconds

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import random
import time
import matplotlib.pyplot as plt

def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1

    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)

        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)

sizes = [100, 500, 1000, 2000, 5000, 10000]
times = []

for n in sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]

    start_time = time.time()
    quick_sort(arr, 0, len(arr) - 1)
    end_time = time.time()

    times.append(end_time - start_time)
    print(f"n = {n}, Time taken = {end_time - start_time:.6f} seconds")

plt.plot(sizes, times, marker='o', color='green')
plt.title("Quick Sort: Time Taken vs Input Size (n)")
plt.xlabel("Input Size (n)")
plt.ylabel("Time (seconds)")
plt.grid(True)

plt.show()
# Out:
# n = 100, Time taken = 0.000125 seconds
# n = 500, Time taken = 0.000790 seconds
# n = 1000, Time taken = 0.000947 seconds
# n = 2000, Time taken = 0.005802 seconds
# n = 5000, Time taken = 0.006126 seconds
# n = 10000, Time taken = 0.013190 seconds

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Adjusted variables for faster execution
n_list = [500, 1000, 2000, 3000, 4000, 5000]
n_max = n_list[-1]

# %%
from datetime import datetime
import random
import copy
import timeit
import numpy as np

ms = datetime.now().microsecond / 1000
random.seed(ms)

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

# Generate data based on the new n_list
numbers = [random.randint(0, 1000) for _ in range(max(n_list))]
print(f"Generated {len(numbers)} elements for testing.")
# Out:
# Generated 5000 elements for testing.

# %%
a_time = []
b_time = []
c_time = []

for l in n_list:
    subset = numbers[:l]

    a = copy.deepcopy(subset)
    b = copy.deepcopy(subset)
    c = copy.deepcopy(subset)

    # Quick Sort
    start_time = timeit.default_timer()
    quick_sort(a, 0, len(a) - 1)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    # Merge Sort
    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    # Selection Sort
    start_time = timeit.default_timer()
    selection_sort(c)
    c_time.append((timeit.default_timer() - start_time) * 1000)

    print(f"Completed size {l}")

print("Input sizes:", n_list)
print("Quick Sort times (ms):", a_time)
print("Merge Sort times (ms):", b_time)
print("Selection Sort times (ms):", c_time)
# Out:
# Completed size 500
# Completed size 1000
# Completed size 2000
# Completed size 3000
# Completed size 4000
# Completed size 5000
# Input sizes: [500, 1000, 2000, 3000, 4000, 5000]
# Quick Sort times (ms): [0.46092299999145325, 0.8587590000388445, 2.2552489999725367, 3.4143740001582046, 4.8894840001594275, 6.825796999919476]
# Merge Sort times (ms): [0.7392720001462294, 1.5027659999304888, 4.02611499998784, 5.179223000141064, 7.034350999902017, 9.293009999964852]
# Selection Sort times (ms): [5.522751999933462, 19.111504999955287, 73.17553600000792, 168.13216700006706, 638.9770739999676, 886.5826839999045]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(n_list, a_time, label="Quicksort", linewidth=1, marker="o")
plt.plot(n_list, b_time, label="Mergesort", linewidth=1, marker="o")
plt.plot(n_list, c_time, label="Selection sort", linewidth=1, marker="o")

plt.title("Compare Sorting Algorithms", fontsize=14)
plt.ylabel("Time (ms)")
plt.xlabel("Input Size (n)")
plt.legend(loc="best")
plt.grid(True)
plt.yscale("log")
plt.show()
