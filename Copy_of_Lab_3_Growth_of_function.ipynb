# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
import matplotlib.pyplot as plt

# %%
def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
def is_even_or_odd(number):
    return "Even" if number % 2 == 0 else "Odd"

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    is_even_or_odd(n)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Even/Odd Check")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
def count_greater_than_zero(numbers):
    count = 0
    for num in numbers:
        if num > 0:
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(-n // 2, n // 2 + 1))
    count_greater_than_zero(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity for Counting Positive Numbers")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

import math

n_values = [2**i for i in range(1, 10)]
time_values = []

for n in n_values:
    data = list(range(n))
    target = n - 1
    binary_search(data, target)
    time_values.append(math.log2(n))

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(log n) Logarithmic Time Complexity (Binary Search)")
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)

def merge(left, right):
    merged = []
    left_idx, right_idx = 0, 0

    while left_idx < len(left) and right_idx < len(right):
        if left[left_idx] < right[right_idx]:
            merged.append(left[left_idx])
            left_idx += 1
        else:
            merged.append(right[right_idx])
            right_idx += 1

    merged.extend(left[left_idx:])
    merged.extend(right[right_idx:])
    return merged

import math
import random

n_values = list(range(1, 201, 10))
time_values = []

for n in n_values:
    data = [random.randint(0, 1000) for _ in range(n)]
    merge_sort(data)
    if n > 0:
      time_values.append(n * math.log2(n))
    else:
      time_values.append(0)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n log n) Log-Linear Time Complexity (Merge Sort)")
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
def polynomial_time_example(n):
    count = 0
    for i in range(n):
        for j in range(n):
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    polynomial_time_example(n)
    time_values.append(n**2)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n^2) Polynomial Time Complexity (Nested Loops)")
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
def fibonacci_recursive(n):
    if n <= 1:
        return n
    else:
        return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)


n_values = list(range(1, 20))
time_values = []


for n in n_values:

    time_values.append(2**n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(2^n) Exponential Time Complexity (Recursive Fibonacci)")
plt.yscale('log')
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
import numpy as np

n_values = np.arange(1, 100)

time_constant = np.ones_like(n_values)
time_log_n = np.log(n_values)
time_linear = n_values
time_n_log_n = n_values * np.log(n_values)
time_polynomial = n_values**2
time_exponential = 2** (n_values / 10)

plt.figure(figsize=(12, 8))

plt.plot(n_values, time_constant, label='O(1) - Constant', linestyle='-')
plt.plot(n_values, time_log_n, label='O(log n) - Logarithmic', linestyle='--')
plt.plot(n_values, time_linear, label='O(n) - Linear', linestyle='-.')
plt.plot(n_values, time_n_log_n, label='O(n log n) - Log-Linear', linestyle=':')
plt.plot(n_values, time_polynomial, label='O(n^2) - Polynomial', linestyle='-')
plt.plot(n_values, time_exponential, label='O(2^n) - Exponential', linestyle='--')

plt.xlabel("Input size n")
plt.ylabel("Time Complexity")
plt.title("Comparison of Common Time Complexities")
plt.legend()
plt.ylim(0, 500)
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 8))
plt.plot(n_values, time_constant, label='O(1) - Constant', linestyle='-')
plt.plot(n_values, time_log_n, label='O(log n) - Logarithmic', linestyle='--')
plt.plot(n_values, time_linear, label='O(n) - Linear', linestyle='-.')
plt.plot(n_values, time_n_log_n, label='O(n log n) - Log-Linear', linestyle=':')
plt.plot(n_values, time_polynomial, label='O(n^2) - Polynomial', linestyle='-')
plt.plot(n_values, time_exponential, label='O(2^n) - Exponential', linestyle='--')

plt.xlabel("Input size n")
plt.ylabel("Time Complexity")
plt.title("Comparison of Common Time Complexities (Log Scale Y-axis)")
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

import time
import random

n_values = list(range(10, 1000, 50))
time_measurements = []

for n in n_values:
    data = [random.randint(0, 1000) for _ in range(n)]
    start_time = time.time()
    quick_sort(data)
    end_time = time.time()
    time_measurements.append((end_time - start_time) * 1000)

plt.figure()
plt.plot(n_values, time_measurements, label='Actual Quick Sort Time')
plt.plot(n_values, n_values * np.log(n_values) / 100, label='O(n log n) (Theoretical)', linestyle='--')
plt.xlabel("Input size n")
plt.ylabel("Time (milliseconds)")
plt.title("Quick Sort Time Complexity (Average Case O(n log n))")
plt.legend()
plt.grid(True)
plt.show()
